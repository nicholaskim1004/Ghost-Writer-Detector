# %% [markdown]
# ## Ghost Writer Detector Data Prep

# %%
from lyricsgenius import Genius
import pandas as pd
import time
import re

# -----------------------------
# CONFIGURATION
# -----------------------------
with open("genius_token.txt", "r") as f:
    token = f.read().strip()

genius = Genius(token, timeout=20, sleep_time=3, retries=5)

# List of artists
artists = ["Mac Miller", "Kendrick Lamar", "Quentin Miller", "Drake", "J. Cole", "A Tribe Called Quest", "Kanye West", "Soulja Boy","Jay-Z", "Big L", "Children of the Corn","Tyler, The Creator", "2Pac", "Joey Bada$$"]

# Optionally: limit to certain albums for each artist
# Leave list empty [] to pull all albums
target_albums = {
    "Mac Miller": ["Swimming", "Circles", "K.I.D.S.", "The Divine Feminine", "Faces"],
    "Kendrick Lamar": ["DAMN.", "good kid, m.A.A.d city", "To Pimp a Butterfly", "Mr. Morale & the Big Steppers", "Section.80","untitled unmastered.", "Black Panther: The Album"],
    "Quentin Miller": ["Essentials, Vol. 2", "Q.M.", "Hey! Thanks a Lot 3", "na fr.", "Falco", "X.X.","Hey! Thanks a Lot 2", "Shredded Metal"],
    "Drake": ["So Far Gone", "Take Care", "Nothing Was the Same", "If You're Reading This It's Too Late", "More Life", "Scorpion", "Certified Lover Boy"],
    "J. Cole": ["The Warm Up", "Friday Night Lights", "Cole World: The Sideline Story", "2014 Forest Hills Drive", "4 Your Eyez Only", "KOD"],
    "A Tribe Called Quest": ["People’s Instinctive Travels and the Paths of Rhythm", "The Low End Theory", "Midnight Marauders", "The Anthology","We got it from Here... Thank You 4 Your service","The Lost Tribes"],
    "Kanye West": ["The College Dropout", "Late Registration", "Graduation", "808s & Heartbreak", "My Beautiful Dark Twisted Fantasy", "The Life of Pablo"],
    "Soulja Boy": ["Pretty Boy Millionaires", "Greatest Entertainer Alive", "Tell Em Tv", "iSouljaBoyTellem","The DeAndre Way","Supaman", "Unsigned and Still Major: Da Album Before Da Album", "souljaboytellem.com", "The Teen of the South", "P.B.M. Pretty Boy Millionaires (Streaming Version)"],
    "Jay-Z": ["Reasonable Doubt", "The Blueprint", "The Black Album", "The Blueprint 3", "Watch the Throne", "4:44"],
    "Big L": ["Now or Never", "The Danger Zone", "Return of the Devil's Son", "139 & Lenox", "Lifestylez Ov Da Poor & Dangerous","Devil’s Son EP (From The Vaults)", "Harlem’s Finest: Return of the King"],
    "Children of the Corn": ["Children of the Corn: Collector’s Edition", "Welcome to the Dangerzone"],
    "Tyler, The Creator": ["Bastard", "Goblin", "Flower Boy", "IGOR", "CALL ME IF YOU GET LOST: The Estate Sale", "CHROMAKOPIA"],
    "2Pac": ["Greatest Hits", "I Ain't Mad At 'Cha", "All Eyez On Me", "Strictly 4 My N.I.G.G.A.Z...", "Me Against The World", "So Many Tears"],
    "Joey Bada$$": ["1999", "B4.DA.$$", "ALL-AMERIKKKAN BADA$$", "The Light Pack", "2000", "Rejex"]
}

# -----------------------------
# FUNCTION DEFINITIONS
# -----------------------------

def get_artist_id(artist_name):
    """Search Genius API for an artist's ID."""
    try:
        search = genius.search_artists(artist_name)
        return search["sections"][0]["hits"][0]["result"]["id"]
    except Exception as e:
        print(f"⚠️ Could not find artist ID for {artist_name}: {e}")
        return None


def get_albums_by_artist(artist_id):
    """Return all albums for a given artist ID."""
    all_albums = []
    page = 1
    while True:
        response = genius.artist_albums(artist_id, page=page)
        albums_page = response.get("albums", [])
        if not albums_page:
            break
        all_albums.extend(albums_page)
        page += 1
    return [
        {"album_name": a["name"], "album_id": a["id"], "url": a["url"]}
        for a in all_albums
    ]


def get_album_tracks(album_id):
    """Fetch all tracks for a Genius album safely."""
    all_tracks = []
    page = 1
    while True:
        try:
            response = genius._make_request(
                f"albums/{album_id}/tracks",
                params_={"page": page},
                public_api=True
            )
        except AssertionError as e:
            if "403" in str(e):
                print(f"🚫 Forbidden: no access to album {album_id}")
            elif "404" in str(e):
                print(f"❌ Album {album_id} not found")
            else:
                print(f"⚠️ Unexpected error fetching album {album_id}: {e}")
            break  # stop paging if request fails

        # safely extract tracks
        page_tracks = response.get("tracks", [])
        if not page_tracks:
            break
        all_tracks.extend(page_tracks)
        page += 1
    return [
        {"song_id": t["song"]["id"], "song_title": t["song"]["title"], "date": t["song"]["release_date_for_display"],"url": t["song"]["url"]}
        for t in all_tracks
    ]


def get_lyrics(url):
    """Fetch lyrics safely."""
    try:
        return genius.lyrics(song_url=url)
    except AssertionError as e:
        if "403" in str(e):
            print(f"🚫 Lyrics not accessible for {url}")
        else:
            print(f"⚠️ AssertionError fetching lyrics: {e}")
        return None
    except Exception as e:
        print(f"⚠️ Error fetching lyrics from {url}: {e}")
        return None
    
def safe_get_writers(songid, artist_name):
    """Safely get writer credits for a Genius song ID."""
    try:
        song_data = genius.song(songid)
        if song_data and 'song' in song_data:
            writers_cred = song_data['song'].get('writer_artists', [])
            return [w['name'] for w in writers_cred] if writers_cred else [artist_name]
        else:
            return [artist_name]
    except AssertionError as e:
        if "403" in str(e):
            print(f"🚫 Skipping song {songid} — 403 Forbidden (private/unreleased)")
        else:
            print(f"⚠️ AssertionError on song {songid}: {e}")
        return [artist_name]
    except Exception as e:
        print(f"⚠️ Unexpected error on song {songid}: {e}")
        return [artist_name]
    
def safe_get_song(songid):
    """Wrapper for genius.song() to handle rate limits and HTML responses safely."""
    try:
        return genius.song(songid)
    except AssertionError as e:
        if "403" in str(e):
            print(f"🚫 Forbidden: Song {songid} (private/unreleased)")
        elif "429" in str(e):
            print(f"⏳ Rate limit hit — sleeping before retry...")
            time.sleep(10)
            return safe_get_song(songid)
        else:
            print(f"⚠️ AssertionError on song {songid}: {e}")
        return None
    except Exception as e:
        print(f"⚠️ Unexpected error on song {songid}: {e}")
        return None



# -----------------------------
# MAIN LOOP
# -----------------------------

all_results = []
seen_tracks = set()

for artist_name in artists:
    print(f"\n🎤 Processing artist: {artist_name}")
    artist_id = get_artist_id(artist_name)
    if artist_id is None:
        continue

    albums = get_albums_by_artist(artist_id)
    if not albums:
        print(f"  ⚠️ No albums found for {artist_name}")
        continue

    df_albums = pd.DataFrame(albums)

    # Filter if target albums specified
    if target_albums.get(artist_name):
        df_albums = df_albums[df_albums["album_name"].isin(target_albums[artist_name])]

    for _, album_row in df_albums.iterrows():
        album_name = album_row["album_name"]
        album_id = album_row["album_id"]
        print(f"  💿 Getting tracks for album: {album_name}")

        tracks = get_album_tracks(album_id)
        for t in tracks:
            songid = t['song_id']
            if songid not in seen_tracks:
                seen_tracks.add(songid)
                print(f"     🎶 {t['song_title']}")
                lyrics = get_lyrics(t["url"])
                
                writers = safe_get_writers(songid, artist_name)
                
                all_results.append({
                    "artist": artist_name,
                    "album": album_name,
                    "song_title": t["song_title"],
                    "date": t['date'],
                    "writers": writers,
                    "lyrics": lyrics
                })
                time.sleep(1)  # be nice to the API
                
for artist_name in artists:
    print(f"\n🎤 Processing artist: {artist_name}")
    artist_id = get_artist_id(artist_name)
    if artist_id is None:
        continue
    newest_50 = genius.artist_songs(artist_id, sort='release_date', per_page=50)
    print(f"  🚀 Getting latest songs from: {artist_name}")
    for t in newest_50['songs']:
        songid = t['id']
        if songid not in seen_tracks:
            seen_tracks.add(songid)
            s = safe_get_song(songid)
            if not s or 'song' not in s:
                continue  # skip this song safely

            album_data = s['song'].get('album')
            album_name = album_data['name'] if album_data else None
           
            print(f"     🎶 {t['title']}")
            lyrics = get_lyrics(t["url"])
            
            writers = safe_get_writers(songid, artist_name)
            
            all_results.append({
                "artist": artist_name,
                "album": album_name,
                "song_title": t["title"],
                "date": t["release_date_for_display"],
                "writers": writers,
                "lyrics": lyrics
            })
            time.sleep(1)
    popular_50 = genius.artist_songs(artist_id, sort='popularity', per_page=50)
    print(f"  🔥 Getting most popular tracks from: {artist_name}")
    for t in popular_50['songs']:
        songid = t['id']
        if songid not in seen_tracks:
            seen_tracks.add(songid)
            s = safe_get_song(songid)
            if not s or 'song' not in s:
                continue  # skip this song safely

            album_data = s['song'].get('album')
            album_name = album_data['name'] if album_data else None
            
            print(f"     🎶 {t['title']}")
            lyrics = get_lyrics(t["url"])
            
            writers = safe_get_writers(songid, artist_name)
            
            all_results.append({
                "artist": artist_name,
                "album": album_name,
                "song_title": t["title"],
                "date": t["release_date_for_display"],
                "writers": writers,
                "lyrics": lyrics
            })
            time.sleep(1)

# -----------------------------
# SAVE RESULTS
# -----------------------------
df = pd.DataFrame(all_results)
df['artist'] = df['artist'].replace('Children of the Corn', 'Big L')

#removing songs that do not have lyrics
filtered = df[df['lyrics'].notna()]
filtered.head()

print(f"\n✅ Done! Collected {len(filtered)} total songs across {filtered['artist'].nunique()} artists.")
# Out:
# 🎤 Processing artist: Mac Miller
#   💿 Getting tracks for album: Circles
#      🎶 Circles
#      🎶 Complicated
#      🎶 Blue World
#      🎶 Good News
#      🎶 I Can See
#      🎶 Everybody
#      🎶 Woods
#      🎶 Hand Me Downs
#      🎶 That’s on Me
#      🎶 Hands
#      🎶 Surf
#      🎶 Once a Day
#   💿 Getting tracks for album: Swimming
#      🎶 Come Back to Earth
#      🎶 Hurt Feelings
#      🎶 What’s the Use?
#      🎶 Perfecto
#      🎶 Self Care
#      🎶 Wings
#      🎶 Ladders
#      🎶 Small Worlds
#      🎶 Conversation, Pt. 1
#      🎶 Dunno
#      🎶 Jet Fuel
#      🎶 2009
#      🎶 So It Goes
#   💿 Getting tracks for album: The Divine Feminine
#      🎶 Congratulations
#      🎶 Dang!
#      🎶 Stay
#      🎶 Skin
#      🎶 Cinderella
#      🎶 Planet God Damn
#      🎶 Soulmate
#      🎶 We
#      🎶 My Favorite Part
#      🎶 God Is Fair, Sexy Nasty
#   💿 Getting tracks for album: Faces
#      🎶 Inside Outside
#      🎶 Here We Go
#      🎶 Friends
#      🎶 Angel Dust
#      🎶 Malibu
#      🎶 What Do You Do
#      🎶 It Just Doesn’t Matter
#      🎶 Therapy
#      🎶 Polo Jeans
#      🎶 Happy Birthday
#      🎶 Wedding
#      🎶 Funeral
#      🎶 Diablo
#      🎶 Ave Maria
#      🎶 55
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Mac-miller-55-lyrics
#      🎶 San Francisco
#      🎶 Colors and Shapes
#      🎶 Insomniak
#      🎶 Uber
#      🎶 Rain
#      🎶 Apparition
#      🎶 Thumbalina
#      🎶 New Faces v2
#      🎶 Grand Finale
#   💿 Getting tracks for album: K.I.D.S.
#      🎶 Kickin’ Incredibly Dope Shit (Intro)
#      🎶 Outside
#      🎶 Get Em Up
#      🎶 Nikes on My Feet
#      🎶 Senior Skip Day
#      🎶 The Spins
#      🎶 Traffic in the Sky
#      🎶 Don’t Mind If I Do
#      🎶 Paper Route
#      🎶 Good Evening
#      🎶 Ride Around
#      🎶 Knock Knock
#      🎶 Mad Flava, Heavy Flow (Interlude)
#      🎶 Kool Aid & Frozen Pizza
#      🎶 All I Want Is You
#      🎶 Poppy
#      🎶 Face in the Crowd
#      🎶 La La La La
#
# 🎤 Processing artist: Kendrick Lamar
#   💿 Getting tracks for album: Black Panther: The Album
#      🎶 Black Panther
#      🎶 All The Stars (Album Version)
#      🎶 X
#      🎶 The Ways
#      🎶 Opps
#      🎶 I Am
#      🎶 Paramedic!
#      🎶 Bloody Waters
#      🎶 King’s Dead
#      🎶 Redemption Interlude
#      🎶 Redemption
#      🎶 Seasons
#      🎶 Big Shot
#      🎶 Pray For Me
#   💿 Getting tracks for album: DAMN.
#      🎶 BLOOD.
#      🎶 DNA.
#      🎶 YAH.
#      🎶 ELEMENT.
#      🎶 FEEL.
#      🎶 LOYALTY.
#      🎶 PRIDE.
#      🎶 HUMBLE.
#      🎶 LUST.
#      🎶 LOVE.
#      🎶 XXX.
#      🎶 FEAR.
#      🎶 GOD.
#      🎶 DUCKWORTH.
#   💿 Getting tracks for album: untitled unmastered.
#      🎶 untitled 01 | 08.19.2014.
#      🎶 untitled 02 | 06.23.2014.
#      🎶 untitled 03 | 05.28.2013.
#      🎶 untitled 04 | 08.14.2014.
#      🎶 untitled 05 | 09.21.2014.
#      🎶 untitled 06 | 06.30.2014.
#      🎶 untitled 07 | 2014-2016
#      🎶 untitled 08 | 09.06.2014.
#   💿 Getting tracks for album: To Pimp a Butterfly
#      🎶 Wesley’s Theory
#      🎶 For Free? (Interlude)
#      🎶 King Kunta
#      🎶 Institutionalized
#      🎶 These Walls
#      🎶 u
#      🎶 Alright
#      🎶 For Sale? (Interlude)
#      🎶 Momma
#      🎶 Hood Politics
#      🎶 How Much a Dollar Cost
#      🎶 Complexion (A Zulu Love)
#      🎶 The Blacker the Berry
#      🎶 You Ain’t Gotta Lie (Momma Said)
#      🎶 i
#      🎶 Mortal Man
#   💿 Getting tracks for album: good kid, m.A.A.d city
#      🎶 Sherane a.k.a Master Splinter’s Daughter
#      🎶 Bitch, Don’t Kill My Vibe
#      🎶 Backseat Freestyle
#      🎶 The Art of Peer Pressure
#      🎶 Money Trees
#      🎶 Poetic Justice
#      🎶 good kid
#      🎶 m.A.A.d city
#      🎶 Swimming Pools (Drank)
#      🎶 Sing About Me, I’m Dying of Thirst
#      🎶 Real
#      🎶 Compton
#      🎶 Bitch, Don’t Kill My Vibe (Remix)
#   💿 Getting tracks for album: Section.80
#      🎶 Fuck Your Ethnicity
#      🎶 Hol’ Up
#      🎶 A.D.H.D
#      🎶 No Make-Up (Her Vice)
#      🎶 Tammy’s Song (Her Evils)
#      🎶 Chapter Six
#      🎶 Ronald Reagan Era (His Evils)
#      🎶 Poe Mans Dreams (His Vice)
#      🎶 The Spiteful Chant
#      🎶 Chapter Ten
#      🎶 Keisha’s Song (Her Pain)
#      🎶 Rigamortis
#      🎶 Kush & Corinthians (His Pain)
#      🎶 Blow My High (Members Only)
#      🎶 Ab-Soul’s Outro
#      🎶 HiiiPoWeR
#
# 🎤 Processing artist: Quentin Miller
#   💿 Getting tracks for album: Essentials, Vol. 2
#      🎶 Emerald Freestyle. (Essential Version)
#      🎶 What It Takes. (Essential Version)
#      🎶 Uknew.
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-uknew-lyrics
# 🚫 Skipping song 12194083 — 403 Forbidden (private/unreleased)
#      🎶 Read Between The Lines.
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-read-between-the-lines-lyrics
# 🚫 Skipping song 12194084 — 403 Forbidden (private/unreleased)
#      🎶 Say It Better. (Essential Version)
#      🎶 Legend has it.
#      🎶 Don’t Be Mad.
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-dont-be-mad-lyrics
# 🚫 Skipping song 12194087 — 403 Forbidden (private/unreleased)
#      🎶 Burnout.
#      🎶 Shine All Summer. (Essential Version)
#      🎶 Icon Dreams. (Essential Version)
#      🎶 Put Me Down.
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-and-bump-j-put-me-down-lyrics
# 🚫 Skipping song 12194090 — 403 Forbidden (private/unreleased)
#      🎶 Callin’ me. (Essential Version)
#      🎶 Don’t Play. (Essential Version)
#      🎶 Love Yourself. (Essential Version)
#      🎶 Hibachi.
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-strap-and-shad-da-god-hibachi-lyrics
# 🚫 Skipping song 12194094 — 403 Forbidden (private/unreleased)
#      🎶 Synergy. (Essential Version)
#      🎶 1 thing. (Essential Version)
#      🎶 Westwood.
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-and-jay-305-westwood-lyrics
# 🚫 Skipping song 12194097 — 403 Forbidden (private/unreleased)
#      🎶 Vibrate High. (Essential Version)
#      🎶 Too Far Gone.
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-too-far-gone-lyrics
# 🚫 Skipping song 12194099 — 403 Forbidden (private/unreleased)
#      🎶 Decisions.
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-decisions-lyrics
# 🚫 Skipping song 12194100 — 403 Forbidden (private/unreleased)
#      🎶 It was all so simple. (Essential Version)
#   💿 Getting tracks for album: na fr.
#      🎶 na fr.
#      🎶 Senseless.
#      🎶 Stuck Up.
#      🎶 Pop-up.
#      🎶 Love Costs.
#      🎶 Spectacular.
#      🎶 Contingency plan.
#      🎶 Still Standin’ (Extended Version)
#   💿 Getting tracks for album: X.X.
#      🎶 Problem Solved
#      🎶 Do You Have the Time???
#      🎶 High Level
#      🎶 Put Nothing Past You...
#      🎶 S.O.S.
#      🎶 Playmaker
#      🎶 Chris Angel
#      🎶 Good News
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-dom-kennedy-and-jdr-good-news-lyrics
#      🎶 Peace
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-peace-lyrics
#      🎶 Lost in It All
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-lost-in-it-all-lyrics
#   💿 Getting tracks for album: Q.M.
#      🎶 Cold Day in Hell...
#      🎶 High Speed Chase...
#      🎶 Hot N’ Cold
#      🎶 Wwtd Interlude...
#      🎶 _A_
#      🎶 Arkham Asylum...
#      🎶 Values...
#      🎶 The Source...
#      🎶 Bank!!!
#      🎶 Scenic Route...
#      🎶 Closing Statements...
#   💿 Getting tracks for album: Falco
#      🎶 Still Here
#      🎶 Surreal
#      🎶 Just in Case
#      🎶 Fax
#      🎶 Gambles
#      🎶 Warp Speed
#      🎶 The Light
#      🎶 Judge Dread
#      🎶 Out of My Hands
#   💿 Getting tracks for album: Hey! Thanks a Lot 3
#      🎶 Thanks from Slink
#      🎶 Progress
#      🎶 Deep
#      🎶 Sum Different x Thanks from Ricky
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-and-ricky-himself-sum-different-x-thanks-from-ricky-lyrics
# 🚫 Skipping song 5519789 — 403 Forbidden (private/unreleased)
#      🎶 Grand
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-and-gizzle-grand-lyrics
# 🚫 Skipping song 5519790 — 403 Forbidden (private/unreleased)
#      🎶 What They Didn’t Want
#      🎶 Fleece
#      🎶 Thanks from Juicy
#      🎶 Litkit
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-litkit-lyrics
# 🚫 Skipping song 5519792 — 403 Forbidden (private/unreleased)
#      🎶 Potential
#      🎶 Half
#      🎶 Choze
#      🎶 D’Angelo
#      🎶 To Turning 26...
#   💿 Getting tracks for album: Shredded Metal
#      🎶 4Real
#      🎶 What A Time...
#      🎶 Bad Influence
#      🎶 No Scrimage
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-and-thecoolismac-no-scrimage-lyrics
# 🚫 Skipping song 5552631 — 403 Forbidden (private/unreleased)
#      🎶 Grey Steel
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-and-cj-francis-iv-grey-steel-lyrics
# 🚫 Skipping song 5552632 — 403 Forbidden (private/unreleased)
#   💿 Getting tracks for album: Hey! Thanks a Lot 2
#      🎶 Intro
#      🎶 Thanks2You
#      🎶 Cinematic
#      🎶 Thanks From Toronto
#      🎶 Leanonme - Wdng
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-and-thecoolismac-leanonme-wdng-lyrics
# 🚫 Skipping song 5517908 — 403 Forbidden (private/unreleased)
#      🎶 Kellyslate (Pennstate)
#      🎶 Hs17
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-migo-jerz-and-thecoolismac-hs17-lyrics
# 🚫 Skipping song 5517909 — 403 Forbidden (private/unreleased)
#      🎶 Changeless
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-changeless-lyrics
# 🚫 Skipping song 5517910 — 403 Forbidden (private/unreleased)
#      🎶 Outro
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Quentin-miller-outro-lyrics
# 🚫 Skipping song 5517911 — 403 Forbidden (private/unreleased)
#      🎶 Thewinter (Bonus)
#
# 🎤 Processing artist: Drake
#   💿 Getting tracks for album: Certified Lover Boy
#      🎶 Champagne Poetry
#      🎶 Papi’s Home
#      🎶 Girls Want Girls
#      🎶 In The Bible
#      🎶 Love All
#      🎶 Fair Trade
#      🎶 Way 2 Sexy
#      🎶 TSU
#      🎶 N 2 Deep
#      🎶 Pipe Down
#      🎶 Yebba’s Heartbreak
#      🎶 No Friends In The Industry
#      🎶 Knife Talk
#      🎶 7am On Bridle Path
#      🎶 Race My Mind
#      🎶 Fountains
#      🎶 Get Along Better
#      🎶 You Only Live Twice
#      🎶 IMY2
#      🎶 Fucking Fans
#      🎶 The Remorse
#   💿 Getting tracks for album: Scorpion
#      🎶 Survival
#      🎶 Nonstop
#      🎶 Elevate
#      🎶 Emotionless
#      🎶 God’s Plan
#      🎶 I’m Upset
#      🎶 8 Out of 10
#      🎶 Mob Ties
#      🎶 Can’t Take a Joke
#      🎶 Sandra’s Rose
#      🎶 Talk Up
#      🎶 Is There More
#      🎶 Peak
#      🎶 Summer Games
#      🎶 Jaded
#      🎶 Nice For What
#      🎶 Finesse
#      🎶 Ratchet Happy Birthday
#      🎶 That’s How You Feel
#      🎶 Blue Tint
#      🎶 In My Feelings
#      🎶 Don’t Matter to Me
#      🎶 After Dark
#      🎶 Final Fantasy
#      🎶 March 14
#   💿 Getting tracks for album: More Life
#      🎶 Free Smoke
#      🎶 No Long Talk
#      🎶 Passionfruit
#      🎶 Jorja Interlude
#      🎶 Get It Together
#      🎶 Madiba Riddim
#      🎶 Blem
#      🎶 4422
#      🎶 Gyalchester
#      🎶 Skepta Interlude
#      🎶 Portland
#      🎶 Sacrifices
#      🎶 Nothings Into Somethings
#      🎶 Teenage Fever
#      🎶 KMT
#      🎶 Lose You
#      🎶 Can’t Have Everything
#      🎶 Glow
#      🎶 Since Way Back
#      🎶 Fake Love
#      🎶 Ice Melts
#      🎶 Do Not Disturb
#      🎶 More Life: Editor’s Note
#   💿 Getting tracks for album: Nothing Was the Same
#      🎶 Tuscan Leather
#      🎶 Furthest Thing
#      🎶 Started from the Bottom
#      🎶 Wu-Tang Forever
#      🎶 Own It
#      🎶 Worst Behavior
#      🎶 From Time
#      🎶 Hold On, We’re Going Home
#      🎶 Connect
#      🎶 The Language
#      🎶 305 to My City
#      🎶 Too Much
#      🎶 Pound Cake / Paris Morton Music 2
#      🎶 Come Thru
#      🎶 All Me
#      🎶 The Motion
#   💿 Getting tracks for album: Take Care
#      🎶 Over My Dead Body
#      🎶 Shot for Me
#      🎶 Headlines
#      🎶 Crew Love
#      🎶 Take Care
#      🎶 Marvins Room
#      🎶 Buried Alive Interlude
#      🎶 Under Ground Kings
#      🎶 We’ll Be Fine
#      🎶 Make Me Proud
#      🎶 Lord Knows
#      🎶 Cameras
#      🎶 Good Ones Go (Interlude)
#      🎶 Doing It Wrong
#      🎶 The Real Her
#      🎶 Look What You’ve Done
#      🎶 HYFR (Hell Ya Fucking Right)
#      🎶 Practice
#      🎶 The Ride
#      🎶 The Motto
#      🎶 Hate Sleeping Alone
#      🎶 The Motto (Remix)
#   💿 Getting tracks for album: So Far Gone
#      🎶 Lust for Life
#      🎶 Houstatlantavegas
#      🎶 Successful
#      🎶 Let’s Call It Off
#      🎶 November 18th
#      🎶 Ignant Shit
#      🎶 A Night Off
#      🎶 Say What’s Real
#      🎶 Little Bit
#      🎶 Best I Ever Had
#      🎶 Unstoppable
#      🎶 Uptown
#      🎶 Sooner Than Later
#      🎶 Bria’s Interlude
#      🎶 The Calm
#      🎶 Outro
#      🎶 Brand New
#      🎶 Congratulations
#
# 🎤 Processing artist: J. Cole
#   💿 Getting tracks for album: KOD
#      🎶 Intro (KOD)
#      🎶 KOD
#      🎶 Photograph
#      🎶 The Cut Off
#      🎶 ATM
#      🎶 Motiv8
#      🎶 Kevin’s Heart
#      🎶 BRACKETS
#      🎶 Once an Addict (Interlude)
#      🎶 FRIENDS
#      🎶 Window Pain (Outro)
#      🎶 1985
#   💿 Getting tracks for album: 4 Your Eyez Only
#      🎶 For Whom the Bell Tolls
#      🎶 Immortal
#      🎶 Deja Vu
#      🎶 Ville Mentality
#      🎶 She’s Mine, Pt. 1
#      🎶 Change
#      🎶 Neighbors
#      🎶 Foldin Clothes
#      🎶 She’s Mine, Pt. 2
#      🎶 4 Your Eyez Only
#   💿 Getting tracks for album: 2014 Forest Hills Drive
#      🎶 Intro (2014 Forest Hills Drive)
#      🎶 January 28th
#      🎶 Wet Dreamz
#      🎶 03' Adolescence
#      🎶 A Tale of 2 Citiez
#      🎶 Fire Squad
#      🎶 St. Tropez
#      🎶 G.O.M.D.
#      🎶 No Role Modelz
#      🎶 Hello
#      🎶 Apparently
#      🎶 Love Yourz
#      🎶 Note to Self
#   💿 Getting tracks for album: Cole World: The Sideline Story
#      🎶 Intro
#      🎶 Dollar and a Dream III
#      🎶 Can’t Get Enough
#      🎶 Lights Please
#      🎶 Interlude (Sideline Story)
#      🎶 Sideline Story
#      🎶 Mr. Nice Watch
#      🎶 Cole World
#      🎶 In the Morning
#      🎶 Lost Ones
#      🎶 Nobody’s Perfect
#      🎶 Never Told
#      🎶 Rise and Shine
#      🎶 God’s Gift
#      🎶 Breakdown
#      🎶 Work Out
#      🎶 Who Dat
#      🎶 Daddy’s Little Girl
#   💿 Getting tracks for album: Friday Night Lights
#      🎶 Friday Night Lights (Intro)
#      🎶 Too Deep for the Intro
#      🎶 Before I’m Gone
#      🎶 Back to the Topic
#      🎶 You Got It
#      🎶 Villematic
#      🎶 Enchanted
#      🎶 Blow Up
#      🎶 Higher
#      🎶 2Face
#      🎶 The Autograph
#      🎶 Best Friend
#      🎶 Cost Me a Lot
#      🎶 Premeditated Murder
#      🎶 Home for the Holidays
#      🎶 Love Me Not
#      🎶 See World
#      🎶 Farewell
#      🎶 Looking for Trouble
#   💿 Getting tracks for album: The Warm Up
#      🎶 Intro (The Warm Up)
#      🎶 Welcome
#      🎶 Can I Live
#      🎶 Grown Simba
#      🎶 Just to Get By
#      🎶 Dead Presidents II
#      🎶 I Get Up
#      🎶 World is Empty
#      🎶 Dreams
#      🎶 Royal Flush
#      🎶 Dollar and a Dream II
#      🎶 Water Break (Interlude)
#      🎶 Heartache
#      🎶 Get Away
#      🎶 Knock Knock
#      🎶 Ladies
#      🎶 Til’ Infinity
#      🎶 The Badness
#      🎶 Hold It Down
#      🎶 Last Call
#      🎶 Losing My Balance
#
# 🎤 Processing artist: A Tribe Called Quest
#   💿 Getting tracks for album: We got it from Here... Thank You 4 Your service
#      🎶 The Space Program
#      🎶 We the People....
#      🎶 Whateva Will Be
#      🎶 Solid Wall of Sound
#      🎶 Dis Generation
#      🎶 Kids...
#      🎶 Melatonin
#      🎶 Enough!!
#      🎶 Mobius
#      🎶 Black Spasmodic
#      🎶 The Killing Season
#      🎶 Lost Somebody
#      🎶 Movin Backwards
#      🎶 Conrad Tokyo
#      🎶 Ego
#      🎶 The Donald
#   💿 Getting tracks for album: The Lost Tribes
#      🎶 Oh My God (UK Flavour Radio Mix)
#      🎶 Mardi Gras at Midnight
#      🎶 The Remedy
#      🎶 Can I Kick It? (Phase 5 Mix)
#      🎶 Stressed Out (Baby Phife Version)
#      🎶 Scenario (Remix)
#      🎶 ICU (Doin’ It)
#      🎶 It’s Yours
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/A-tribe-called-quest-its-yours-lyrics
# 🚫 Skipping song 5904349 — 403 Forbidden (private/unreleased)
#      🎶 Jam (Remix)
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/A-tribe-called-quest-jam-remix-lyrics
# 🚫 Skipping song 5904350 — 403 Forbidden (private/unreleased)
#      🎶 Game Day
#      🎶 Glamour and Glitz
#      🎶 Weekendz
#      🎶 Hey
#      🎶 Rumble In The Jungle
#      🎶 Practice Session
#      🎶 That Shit
#   💿 Getting tracks for album: The Anthology
#      🎶 Check the Rhime
#      🎶 Bonita Applebum
#      🎶 Award Tour
#      🎶 Can I Kick It?
#      🎶 Scenario
#      🎶 Buggin’ Out
#      🎶 If The Papes Come
#      🎶 Electric Relaxation
#      🎶 Jazz (We’ve Got)
#      🎶 I Left My Wallet in El Segundo
#      🎶 Hot Sex
#      🎶 Oh My God
#      🎶 Stressed Out (Raphael Saadiq Remix)
#      🎶 Luck of Lucien
#      🎶 Description of a Fool
#      🎶 Keeping It Moving
#      🎶 Find a Way
#      🎶 Sucka Nigga
#      🎶 Vivrant Thing
#      🎶 Mr. Incognito
#   💿 Getting tracks for album: Midnight Marauders
#      🎶 Midnight Marauders Tour Guide
#      🎶 Steve Biko (Stir it Up)
#      🎶 8 Million Stories
#      🎶 Midnight
#      🎶 We Can Get Down
#      🎶 Clap Your Hands
#      🎶 Keep It Rollin’
#      🎶 The Chase, Part II
#      🎶 Lyrics to Go
#      🎶 God Lives Through
#      🎶 Celebration
#      🎶 Skit #4
#      🎶 Gone
#      🎶 Diamonds from Sierra Leone
#      🎶 Late
#   💿 Getting tracks for album: The College Dropout
#      🎶 Intro
#      🎶 We Don’t Care
#      🎶 Graduation Day
#      🎶 All Falls Down
#      🎶 I’ll Fly Away
#      🎶 Spaceship
#      🎶 Jesus Walks
#      🎶 Never Let Me Down
#      🎶 Get Em High
#      🎶 Workout Plan
#      🎶 The New Workout Plan
#      🎶 Slow Jamz
#      🎶 Breathe In Breathe Out
#      🎶 School Spirit Skit 1
#      🎶 School Spirit
#      🎶 School Spirit Skit 2
#      🎶 Lil Jimmy Skit
#      🎶 Two Words
#      🎶 Through the Wire
#      🎶 Family Business
#      🎶 Last Call
#
# 🎤 Processing artist: Soulja Boy
#   💿 Getting tracks for album: P.B.M. Pretty Boy Millionaires (Streaming Version)
#      🎶 Cook My Bitch
#      🎶 Swag on My Dick (Remix)
#      🎶 Cooking Dance
#      🎶 Perfect
#      🎶 Rock Ice
#      🎶 All I Know
#      🎶 Gucci Wings
#      🎶 I Got Bitches (SB Remix)
#      🎶 The World So Cold
#      🎶 Meet Young Bitch
#      🎶 I Get Dollaz
#      🎶 B.O.R. (Birth of Rap)
#      🎶 Give Me a Dance
#      🎶 Aye
#      🎶 Bitches Goin Ham
#      🎶 Soulja Boy Speaks
#      🎶 Fuck the World
#      🎶 Im Here
#      🎶 Only God Knows
#      🎶 Pretty Boy Shit
#      🎶 Classical
#      🎶 Fuck Bein Broke
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-and-lil-b-fuck-bein-broke-lyrics
# 🚫 Skipping song 4506252 — 403 Forbidden (private/unreleased)
#      🎶 Swag OD
#      🎶 The Same Thang
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-and-lil-b-the-same-thang-lyrics
# 🚫 Skipping song 4506253 — 403 Forbidden (private/unreleased)
#      🎶 YGRN
#      🎶 Have You Ever (Swerve)
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-and-lil-b-have-you-ever-swerve-lyrics
# 🚫 Skipping song 4506254 — 403 Forbidden (private/unreleased)
#      🎶 The World Is Yours
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-and-lil-b-the-world-is-yours-lyrics
# 🚫 Skipping song 4506255 — 403 Forbidden (private/unreleased)
#   💿 Getting tracks for album: The DeAndre Way
#      🎶 First Day of School
#      🎶 Touchdown
#      🎶 Hey Cutie
#      🎶 Speakers Going Hammer
#      🎶 Pretty Boy Swag
#      🎶 30 Thousand 100 Million
#      🎶 Mean Mug
#      🎶 Blowing Me Kisses
#      🎶 Fly
#      🎶 Grammy
#   💿 Getting tracks for album: Pretty Boy Millionaires
#   💿 Getting tracks for album: Greatest Entertainer Alive
#      🎶 Intro (Greatest Entertainer Alive)
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-intro-greatest-entertainer-alive-lyrics
# 🚫 Skipping song 7003777 — 403 Forbidden (private/unreleased)
#      🎶 What You Know
#      🎶 Got Dammit
#      🎶 Money Gang Rock
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-money-gang-rock-lyrics
# 🚫 Skipping song 5541072 — 403 Forbidden (private/unreleased)
#      🎶 Turn My Swag On (Remix)
#      🎶 Bird Walk
#      🎶 100K [Tell Em Tv]
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-100k-tell-em-tv-lyrics
# 🚫 Skipping song 5158083 — 403 Forbidden (private/unreleased)
#      🎶 Get Money Niggas
#      🎶 Keep It 200
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-keep-it-200-lyrics
# 🚫 Skipping song 7003815 — 403 Forbidden (private/unreleased)
#      🎶 G Walk
#      🎶 Get Em Got Em
#      🎶 New School
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-new-school-lyrics
# 🚫 Skipping song 5157955 — 403 Forbidden (private/unreleased)
#      🎶 Show Out (Remix)
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-show-out-remix-lyrics
# 🚫 Skipping song 7003816 — 403 Forbidden (private/unreleased)
#      🎶 My Dougie (Remix)
#      🎶 Marco Polo
#      🎶 Kiss Me Thru The Phone
#      🎶 Str8 Like That
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-str8-like-that-lyrics
# 🚫 Skipping song 7003832 — 403 Forbidden (private/unreleased)
#      🎶 The Future
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-the-future-lyrics
# 🚫 Skipping song 5127670 — 403 Forbidden (private/unreleased)
#      🎶 Crank That (Soulja Boy)
#      🎶 Greatest Entertainer Alive (Outro)
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-greatest-entertainer-alive-outro-lyrics
# 🚫 Skipping song 7003835 — 403 Forbidden (private/unreleased)
#      🎶 Gucci Bandanna
#   💿 Getting tracks for album: Tell Em Tv
#      🎶 Intro (Tell Em TV)
#      🎶 Boom [Tell Em Tv]
#      🎶 In Da Club Goin Hard
#      🎶 Grind On
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-grind-on-lyrics
# 🚫 Skipping song 5157952 — 403 Forbidden (private/unreleased)
#      🎶 Easy
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-easy-lyrics
# 🚫 Skipping song 5157953 — 403 Forbidden (private/unreleased)
#      🎶 Big Faces
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-big-faces-lyrics
# 🚫 Skipping song 5157954 — 403 Forbidden (private/unreleased)
#      🎶 I Wanna Go
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-i-wanna-go-lyrics
# 🚫 Skipping song 5157956 — 403 Forbidden (private/unreleased)
#      🎶 Interlude (Tell Em TV)
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-interlude-tell-em-tv-lyrics
# 🚫 Skipping song 5157957 — 403 Forbidden (private/unreleased)
#      🎶 Stupid Swag
#      🎶 My Money
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-my-money-lyrics
# 🚫 Skipping song 5157959 — 403 Forbidden (private/unreleased)
#      🎶 Turn My Swag On (Gucci Mane Remix)
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-turn-my-swag-on-gucci-mane-remix-lyrics
# 🚫 Skipping song 7315251 — 403 Forbidden (private/unreleased)
#      🎶 Outro
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-outro-lyrics
# 🚫 Skipping song 5157961 — 403 Forbidden (private/unreleased)
#   💿 Getting tracks for album: iSouljaBoyTellem
#      🎶 I’m Bout Tha Stax
#      🎶 Turn My Swag On
#      🎶 Eazy
#      🎶 Booty Got Swag
#      🎶 Rubber Bands
#      🎶 Hey You There
#      🎶 Yamaha Mama
#      🎶 Wit My Yums On
#      🎶 Go Head
#      🎶 Shoppin’ Spree
#      🎶 Soulja Boy Tellem
#      🎶 Whoop Rico (Remix)
#      🎶 I Pray (Outro)
#   💿 Getting tracks for album: The Teen of the South
#      🎶 MTV Mixtape Monday Intro
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-mtv-mixtape-monday-intro-lyrics
# 🚫 Skipping song 5149927 — 403 Forbidden (private/unreleased)
#      🎶 IDance
#      🎶 I’m Zooted
#      🎶 Gucci Bandanna (Original)
#      🎶 The Teen of the South Interlude
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-the-teen-of-the-south-interlude-lyrics
# 🚫 Skipping song 5149929 — 403 Forbidden (private/unreleased)
#      🎶 I Know You Hate Me
#      🎶 DJ Khaled Interlude
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-dj-khaled-interlude-lyrics
# 🚫 Skipping song 5149931 — 403 Forbidden (private/unreleased)
#      🎶 Photo Shoot
#      🎶 Go Ham On Em
#      🎶 Soula Boy Freestyle
#      🎶 SODMG Interlude
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-sodmg-interlude-lyrics
# 🚫 Skipping song 5149935 — 403 Forbidden (private/unreleased)
#      🎶 The Dre
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-the-dre-lyrics
# 🚫 Skipping song 5149936 — 403 Forbidden (private/unreleased)
#      🎶 Dj Southanbred Interlude
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-dj-southanbred-interlude-lyrics
# 🚫 Skipping song 5149937 — 403 Forbidden (private/unreleased)
#      🎶 Go Hard [The Teen of the South]
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-go-hard-the-teen-of-the-south-lyrics
# 🚫 Skipping song 5149938 — 403 Forbidden (private/unreleased)
#      🎶 Get Silly (Mr. Collipark Remix)
#      🎶 Marco Polo (Original Version)
#      🎶 Where I’m From Interlude
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-where-im-from-interlude-lyrics
# 🚫 Skipping song 5149939 — 403 Forbidden (private/unreleased)
#      🎶 Super Soak
#      🎶 Mr Collipark Outro
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-mr-collipark-outro-lyrics
# 🚫 Skipping song 5149940 — 403 Forbidden (private/unreleased)
#      🎶 Señorita
#      🎶 Shout Outs
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-shout-outs-lyrics
# 🚫 Skipping song 5149942 — 403 Forbidden (private/unreleased)
#      🎶 Donk (Remix)
#   💿 Getting tracks for album: souljaboytellem.com
#      🎶 Intro
#      🎶 Sidekick
#      🎶 Snap and Roll
#      🎶 Bapes
#      🎶 Let Me Get Em
#      🎶 Donk
#      🎶 Yahhh!
#      🎶 Pass It to Arab
#      🎶 Soulja Girl
#      🎶 Booty Meat
#      🎶 Report Card
#      🎶 She Thirsty
#      🎶 Don’t Get Mad
#      🎶 Nope (iTunes Bonus Track)
#   💿 Getting tracks for album: Supaman
#      🎶 Intro (Supaman)
#      🎶 Bring Dat Beat Back
#      🎶 Yahhh Bitch
#      🎶 Crank Dat Dance
#      🎶 Make Ya Face Beat Up My Hands
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-make-ya-face-beat-up-my-hands-lyrics
# 🚫 Skipping song 5149868 — 403 Forbidden (private/unreleased)
#      🎶 Yahoo Hoez
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Soulja-boy-yahoo-hoez-lyrics
# 🚫 Skipping song 5149869 — 403 Forbidden (private/unreleased)
#      🎶 You Got Mail
#      🎶 Yeen Crunk
#      🎶 We Dem 30/30 Boyz
#      🎶 Killin’ Spree
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/
#      🎶 Brooklyn’s Finest
#      🎶 Dead Presidents II
#      🎶 Feelin’ It
#      🎶 D’Evils
#      🎶 22 Two’s
#      🎶 Can I Live
#      🎶 Ain’t No Nigga
#      🎶 Friend or Foe
#      🎶 Coming of Age
#      🎶 Cashmere Thoughts
#      🎶 Bring It On
#      🎶 Regrets
#
# 🎤 Processing artist: Big L
#   💿 Getting tracks for album: Harlem’s Finest: Return of the King
#      🎶 u aint gotta chance
#   💿 Getting tracks for album: Now or Never
#      🎶 Now or Never (Power Moves)
#      🎶 Now or Never (M&G Diner Instrumental)
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Big-l-now-or-never-m-g-diner-instrumental-lyrics
#   💿 Getting tracks for album: Devil’s Son EP (From The Vaults)
#      🎶 Devil’s Son
#      🎶 I Shoulda Used a Rubba
#      🎶 School Dayz
#      🎶 Timez Iz Hard
#      🎶 Da Unexpected Flava
#      🎶 Devil’s Son (Instrumental)
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Big-l-devils-son-instrumental-lyrics
#   💿 Getting tracks for album: The Danger Zone
#      🎶 8 Iz Enuff (Demo Version)
#      🎶 Harlem N.Y.C. (Beats 2 Blow Remix)
#      🎶 You Know What I’m About (Original Version)
#      🎶 98' Halftime Radio
#      🎶 Yours (Get Yours Demo)
#      🎶 Work Part II
#      🎶 Tru Master
#      🎶 Cluemanati (’97 DJ Clue Freestyle)
#      🎶 5 Fingas of Death
#      🎶 Let Me Find Out
#      🎶 We All Can’t Ball
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Big-l-we-all-cant-ball-lyrics
# 🚫 Skipping song 6314427 — 403 Forbidden (private/unreleased)
#      🎶 S.K.I.T.S. (Remix)
#      🎶 Live in Amsterdam
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Big-l-live-in-amsterdam-lyrics
# 🚫 Skipping song 6314428 — 403 Forbidden (private/unreleased)
#      🎶 Raw & Ready
#      🎶 Thick (Rockwilder Mix)
#   💿 Getting tracks for album: 139 & Lenox
#      🎶 On the Mic
#      🎶 Ebonics Remix
#      🎶 We Got This (Alternative Lyrics)
#      🎶 Platinum Plus (Original Riverside Mix)
#      🎶 Furious Anger
#      🎶 Still Here
#      🎶 Games Females Play (If You Not Aware)
#      🎶 Nigga Please
#      🎶 Who You Slidin’ Wit’ (Buckwild Mix)
#      🎶 Universal Freestyle (Harlem World Universal)
#      🎶 Devil’s Son (Live Remix) (Return of the Devil’s Son)
#   💿 Getting tracks for album: Lifestylez Ov Da Poor & Dangerous
#      🎶 Put It On
#      🎶 M.V.P.
#      🎶 No Endz, No Skinz
#      🎶 8 Iz Enuff
#      🎶 All Black
#      🎶 Danger Zone
#      🎶 Street Struck
#      🎶 Da Graveyard
#      🎶 Lifestylez ov da Poor & Dangerous
#      🎶 I Don’t Understand It
#      🎶 Fed Up Wit the Bullshit
#      🎶 Let ’Em Have It “L”
#
# 🎤 Processing artist: Children of the Corn
#   💿 Getting tracks for album: Welcome to the Dangerzone
#      🎶 Harlem U.S.A. (Harlem Version)
#      🎶 American Dream
#      🎶 Harlem Nights
#      🎶 Fair One, Part 1
#      🎶 Give Up the Game
#      🎶 Doin’ It
#      🎶 I Remember When
#      🎶 Harlem U.S.A. (Uptown Version)
#      🎶 Trickin’
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Children-of-the-corn-trickin-lyrics
# 🚫 Skipping song 10613322 — 403 Forbidden (private/unreleased)
#      🎶 American Dream (Demo Version 1)
#      🎶 Biscuits & Bangers
#      🎶 Hard to Get By
#      🎶 Ill Flow
#      🎶 Paint the Town Red
#      🎶 The Corn
#      🎶 Don’t Sleep
#      🎶 Fair One, Part 2
#      🎶 A Star Is Born
#      🎶 American Dream (Demo Version 2)
#   💿 Getting tracks for album: Children of the Corn: Collector’s Edition
#      🎶 Intro
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Children-of-the-corn-intro-lyrics
# 🚫 Skipping song 3503625 — 403 Forbidden (private/unreleased)
#      🎶 Danger Zone
#      🎶 Six Figga (Freestyle)
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Children-of-the-corn-six-figga-freestyle-lyrics
# 🚫 Skipping song 3503628 — 403 Forbidden (private/unreleased)
#      🎶 Stretch and Bobbito ’93 Freestyle
#      🎶 Stretch and Bobbito ’96 Freestyle
#
# 🎤 Processing artist: Tyler, The Creator
#   💿 Getting tracks for album: CHROMAKOPIA
#      🎶 St. Chroma
#      🎶 Rah Tah Tah
#      🎶 Noid
#      🎶 Darling, I
#      🎶 Hey Jane
#      🎶 I Killed You
#      🎶 Judge Judy
#      🎶 Sticky
#      🎶 Take Your Mask Off
#      🎶 Tomorrow
#      🎶 Thought I Was Dead
#      🎶 Like Him
#      🎶 Balloon
#      🎶 I Hope You Find Your Way Home
#   💿 Getting tracks for album: CALL ME IF YOU GET LOST: The Estate Sale
#      🎶 SIR BAUDELAIRE
#      🎶 CORSO
#      🎶 LEMONHEAD
#      🎶 WUSYANAME
#      🎶 LUMBERJACK
#      🎶 HOT WIND BLOWS
#      🎶 MASSA
#      🎶 RUNITUP
#      🎶 MANIFESTO
#      🎶 SWEET / I THOUGHT YOU WANTED TO DANCE
#      🎶 MOMMA TALK
#      🎶 RISE!
#      🎶 BLESSED
#      🎶 JUGGERNAUT
#      🎶 WILSHIRE
#      🎶 SAFARI
#      🎶 EVERYTHING MUST GO
#      🎶 STUNTMAN
#      🎶 WHAT A DAY
#      🎶 WHARF TALK
#      🎶 DOGTOOTH
#      🎶 HEAVEN TO ME
#      🎶 BOYFRIEND, GIRLFRIEND (2020 Demo)
#      🎶 SORRY NOT SORRY
#   💿 Getting tracks for album: IGOR
#      🎶 IGOR’S THEME
#      🎶 EARFQUAKE
#      🎶 I THINK
#      🎶 EXACTLY WHAT YOU RUN FROM YOU END UP CHASING
#      🎶 RUNNING OUT OF TIME
#      🎶 NEW MAGIC WAND
#      🎶 A BOY IS A GUN*
#      🎶 PUPPET
#      🎶 WHAT’S GOOD
#      🎶 GONE, GONE / THANK YOU
#      🎶 I DON’T LOVE YOU ANYMORE
#      🎶 ARE WE STILL FRIENDS?
#   💿 Getting tracks for album: Flower Boy
#      🎶 Foreword
#      🎶 Where This Flower Blooms
#      🎶 Sometimes...
#      🎶 See You Again
#      🎶 Who Dat Boy
#      🎶 Pothole
#      🎶 Garden Shed
#      🎶 Boredom
#      🎶 I Ain’t Got Time!
#      🎶 911 / Mr. Lonely
#   💿 Getting tracks for album: Strictly 4 My N.I.G.G.A.Z...
#      🎶 Holler If Ya Hear Me
#      🎶 Pac’s Theme [Interlude]
#      🎶 Point the Finga
#      🎶 Something 2 Die 4 [Interlude]
#      🎶 Last Wordz
#      🎶 Souljah’s Revenge
#      🎶 Peep Game
#      🎶 Strugglin’
#      🎶 Guess Who’s Back
#      🎶 Representin’ 93
#      🎶 Strictly 4 My N.I.G.G.A.Z...
#      🎶 The Streetz R Deathrow
#      🎶 Papa’z Song
#      🎶 5 Deadly Venomz
#
# 🎤 Processing artist: Joey Bada$$
#   💿 Getting tracks for album: 2000
#      🎶 The Baddest
#      🎶 Make Me Feel
#      🎶 Where I Belong
#      🎶 Brand New 911
#      🎶 Cruise Control
#      🎶 Eulogy
#      🎶 Zipcodes
#      🎶 One of Us
#      🎶 Welcome Back
#      🎶 Show Me
#      🎶 Wanna Be Loved
#      🎶 Let It Breathe
#      🎶 Head High
#      🎶 Survivors Guilt
#      🎶 Written in the Stars
#   💿 Getting tracks for album: The Light Pack
#      🎶 The Light
#      🎶 No Explanation
#      🎶 Shine
#   💿 Getting tracks for album: ALL-AMERIKKKAN BADA$$
#      🎶 GOOD MORNING AMERIKKKA
#      🎶 FOR MY PEOPLE
#      🎶 TEMPTATION
#      🎶 LAND OF THE FREE
#      🎶 DEVASTATED
#      🎶 Y U DON’T LOVE ME? (MISS AMERIKKKA)
#      🎶 ROCKABYE BABY
#      🎶 RING THE ALARM
#      🎶 SUPER PREDATOR
#      🎶 BABYLON
#      🎶 LEGENDARY
#      🎶 AMERIKKKAN IDOL
#   💿 Getting tracks for album: B4.DA.$$
#      🎶 Save the Children
#      🎶 Greenbax (Introlude)
#      🎶 Paper Trail$
#      🎶 Piece of Mind
#      🎶 Big Dusty
#      🎶 Hazeus View
#      🎶 Like Me
#      🎶 Belly of the Beast
#      🎶 No. 99
#      🎶 Christ Conscious
#      🎶 On & On
#      🎶 Escape 120
#      🎶 Black Beetles
#      🎶 O.C.B.
#      🎶 Curry Chicken
#      🎶 Run Up on Ya
#      🎶 Teach Me
#   💿 Getting tracks for album: Rejex
#      🎶 Intro
#      🎶 Blooming Blossoms (Flow-ers Pt.1)
#      🎶 Catharsis
#      🎶 Indubitable
#      🎶 OG Killuminati
#      🎶 PantiE Raid
#      🎶 That Gushy
#      🎶 Fantom
#      🎶 Silent Night
#      🎶 Oh Deer (Beddar Daze)
#      🎶 DSL (Da Special List)
#      🎶 UpDate
#      🎶 Little Rachel
#      🎶 This Feelin’
#   💿 Getting tracks for album: 1999
#      🎶 Summer Knights
#      🎶 Waves
#      🎶 FromdaTomb$
#      🎶 Survival Tactics
#      🎶 Killuminati
#      🎶 Hardknock
#      🎶 World Domination
#      🎶 Pennyroyal
#      🎶 Funky Ho’$
#      🎶 Daily Routine
#      🎶 Snakes
#      🎶 Don’t Front
#      🎶 Righteous Minds
#      🎶 Where It’$ At?
#      🎶 Suspect (Third Eye Shit)
#
# 🎤 Processing artist: Mac Miller
#   🚀 Getting latest songs from: Mac Miller
#      🎶 Carpe Diem
#      🎶 Royal Flush
#      🎶 Cable Box
#      🎶 My Steps
#      🎶 Tambourine Dream
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/
#      🎶 Crazy in Love [Mixed]
#      🎶 So Ambitious [Mixed]
#      🎶 SONG CRY
#      🎶 Empire State of Mind
#      🎶 BIG EVERYTHING (Sped Up)
#      🎶 BIG EVERYTHING (Slowed & Reverb)
#      🎶 7:39
#      🎶 Best of Me, Pt. 2 [Mixed]
#      🎶 Sorry not Sorry
#      🎶 AMERIICAN REQUIEM (Physical Version)
#      🎶 SWEET ★ HONEY ★ BUCKIIN’
#      🎶 YA YA
#      🎶 SWEET ★ HONEY ★ BUCKIIN’ (Physical Version)
#      🎶 SPAGHETTII
#      🎶 AMERIICAN REQUIEM
#      🎶 DAUGHTER
#      🎶 JOLENE
#      🎶 LEVII’S JEANS
#      🎶 Le taxis n’entend pas
#      🎶 Imaginary Players (Mixed)
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Jay-z-imaginary-players-mixed-lyrics
#      🎶 I Want You Forever
#      🎶 Jackin For Beats Freestyle
#      🎶 DONDA VISION
#      🎶 BIG EVERYTHING
#   🔥 Getting most popular tracks from: Jay-Z
#      🎶 Drunk in Love
#      🎶 Holy Grail
#      🎶 The Story of Adidon
#      🎶 Part II (On the Run)
#      🎶 APESHIT
#      🎶 The Worst
#      🎶 Tom Ford
#      🎶 Still D.R.E.
#      🎶 FuckWithMeYouKnowIGotIt
#      🎶 Umbrella
#      🎶 Jail
#      🎶 FRIENDS
#      🎶 Savage Remix
#      🎶 Oceans
#      🎶 Loyal
#      🎶 Suit & Tie
#      🎶 Big Pimpin’
#      🎶 LOVEHAPPY
#      🎶 I Got the Keys
#      🎶 Pop Style
#      🎶 BROWN SKIN GIRL
#      🎶 Drunk In Love (Remix)
#      🎶 Biking
#      🎶 Pop Style (Single Version)
#      🎶 Picasso Baby
#      🎶 Shining
#      🎶 GOD DID
#
# 🎤 Processing artist: Big L
#   🚀 Getting latest songs from: Big L
#      🎶 Def Jam
#      🎶 Def Jam (CLOUD Sounds)
#      🎶 Sangre (CLOUD Sounds)
#      🎶 GUILT TRIPPIN
#      🎶 Corriente
#      🎶 I Shouldah Used a Rubbah
#      🎶 2 Advanced 4 Y’all
#      🎶 The Enemy (Remix)
#      🎶 Daydr3am
#      🎶 Jeszcze mniej MC
#      🎶 L FREES
#      🎶 Big L Freestyle (Remix)
#      🎶 Holy Spirit
#      🎶 Cigarettes and Sunshine
#      🎶 Da Enemy (Showbiz Remix)
#      🎶 Casualties of a Dice Game (9th Wonder Remix)
#      🎶 ALONE
#      🎶 Power Cypha 2 Freestyle ’97
#      🎶 Ya Baby Mutha
#      🎶 The Gug - Snuff Film Club (DJ Rozwell & Yung Puke Unit Remix)
#      🎶 730
#      🎶 Da Enemy (Bink Remix)
#      🎶 Return Of The Twat
#      🎶 Hell Up In Harlem
#      🎶 Queen’s Most
#      🎶 Danger Sequel
#      🎶 Perfect Day
#      🎶 Doo Wop #5
#      🎶 Tony’s Touch
#      🎶 How Will I Make It? (I Won’t)
#      🎶 Principal of the New School
#      🎶 Zone of Danger
#      🎶 Hard to Kill
#      🎶 Audition
#      🎶 Put It On (Kryph VIP)
#      🎶 Give It To ’Em “L” (Original Mix)
#      🎶 Give It To ’Em “L” (OG Instrumental)
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Big-l-give-it-to-em-l-og-instrumental-lyrics
#      🎶 No Endz, No Skinz (Original Mix)
#   🔥 Getting most popular tracks from: Big L
#      🎶 Stretch and Bobbito ’95 Freestyle
#      🎶 ’98 Freestyle
#      🎶 Ebonics
#      🎶 Deadly Combination (Remix)
#      🎶 Deadly Combination
#      🎶 The Enemy
#      🎶 Platinum Plus
#      🎶 Flamboyant
#      🎶 Sandman 118 Freestyle
#      🎶 Day One
#      🎶 The Big Picture (Intro)
#      🎶 Size ’Em Up
#      🎶 Fall Back
#      🎶 Casualties of a Dice Game
#      🎶 The Heist
#      🎶 Holdin’ It Down
#      🎶 You Know What I’m About
#      🎶 Represent
#      🎶 The Triboro
#      🎶 Juice (DJ Cinema remix)
#      🎶 Stretch and Bobbito ’93 Freestyle
#      🎶 Thick
#      🎶 Dangerous
#
# 🎤 Processing artist: Children of the Corn
#   🚀 Getting latest songs from: Children of the Corn
#      🎶 Harlem USA
#   🔥 Getting most popular tracks from: Children of the Corn
#
# 🎤 Processing artist: Tyler, The Creator
#   🚀 Getting latest songs from: Tyler, The Creator
#      🎶 Sugar On My Tongue (Test Pressing Version)
#      🎶 Track 10
#      🎶 Sucka Free
#      🎶 Sucka Free (Test Pressing Version)
#      🎶 Stop Playing With Me
#      🎶 Ring Ring Ring
#      🎶 Ring Ring Ring (Test Pressing Version)
#      🎶 Big Poe (Test Pressing Version)
#      🎶 Don’t Tap That Glass / Tweakin’
#      🎶 Don’t You Worry Baby
#      🎶 Sugar On My Tongue
#      🎶 I’ll Take Care of You
#      🎶 Don’t You Worry Baby (Test Pressing Version)
#      🎶 DON’T TAP THE GLASS (Open Letter)
#      🎶 Don’t Tap That Glass / Tweakin’ (Test Pressing Version)
#      🎶 Tell Me What It Is
#      🎶 Mommanem
#      🎶 Big Poe
#      🎶 P.O.V.
#      🎶 Cracc at 15
#      🎶 Mother [V2]
#      🎶 Get Right
#      🎶 THAT GUY
#      🎶 Sticky (Test Pressing Version)
#      🎶 I Killed You (Test Pressing Version)
#      🎶 Tomorrow (Test Pressing Version)
#      🎶 Sticky (Radio Edit)
#      🎶 Mother
#      🎶 St. Chroma (Test Pressing Version)
#      🎶 Darling, I (Test Pressing Version)
#      🎶 Take Your Mask Off (Test Pressing Version)
#      🎶 Thought I Was Dead (Test Pressing Version)
#      🎶 I Hope You Find Your Way Home (Test Pressing Version)
#      🎶 Like Him (Test Pressing Version)
#   🔥 Getting most popular tracks from: Tyler, The Creator
#      🎶 Oldie
#      🎶 IFHY
#      🎶 Swim Good
#      🎶 Tamale
#      🎶 FUCKING YOUNG / PERFECT
#      🎶 Rusty
#      🎶 SMUCKERS
#      🎶 Domo23
#      🎶 Potato Salad
#      🎶 Futsal Shuffle 2020
#      🎶 Trashwang
#      🎶 Answer
#      🎶 Martians vs. Goblins
#      🎶 Earl
#      🎶 Skyline To
#      🎶 Telephone Calls
#      🎶 Rella
#      🎶 Colossus
#
# 🎤 Processing artist: 2Pac
#      🎶 HIGHROLLER
#      🎶 STILL
#      🎶 DARK AURA
#      🎶 extra points
#      🎶 ABK
#      🎶 1more day
#      🎶 EUPHORIA
#      🎶 New York Knicks Anthem (Remix)
#      🎶 CRASH DUMMY
#      🎶 MY TOWN
#      🎶 THE FINALS
#      🎶 Red Bull Spiral Freestyle
#      🎶 The Louvre
#      🎶 gwood
#      🎶 STiLL i (DENiM DEMO) (i)
#      🎶 Pardon Me
#      🎶 Sorry Not Sorry
#      🎶 $WÅŃK
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/The-masked-ones-wank-lyrics
#      🎶 The Ruler’s Back
#      🎶 They Said He Had A Gun
#      🎶 Fry Plantain
#      🎶 Syrup Sandwiches
#      🎶 FRESHMAN FREESTYLE
#      🎶 9 Mile
#      🎶 Lift Off
#      🎶 Wadibusa
#      🎶 SMH
#      🎶 Ball Alone
#      🎶 Tell Me
#      🎶 Rumble
#      🎶 Blessings
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Neek-bucks-and-joey-bada-blessings-lyrics
#      🎶 ‎i went to school high #🔮🍃🥴
#      🎶 Instinct
#      🎶 STANK ROSE
#      🎶 Khvn Forever
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Katatya-khvn-forever-lyrics
#      🎶 DENiM (B)
#      🎶 DENiM (Instrumental)
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Idk-and-joey-bada-denim-instrumental-lyrics
#   🔥 Getting most popular tracks from: Joey Bada$$
#      🎶 rockstar
#      🎶 infinity (888)
#      🎶 King’s Dead (Freestyle)
#      🎶 Love Is Only a Feeling
#      🎶 95 Til Infinity
#      🎶 Like Water
#      🎶 Unorthodox
#      🎶 327
#      🎶 America
#      🎶 My Yout
#      🎶 XXL Freshmen 2013 Cypher - Part 1
#      🎶 #LongLiveSteelo
#      🎶 Left Hand
#      🎶 Killuminati Pt. 2
#      🎶 Daemons
#      🎶 Enter the Void
#      🎶 Dead Prez
#      🎶 Right on Time
#      🎶 Tree of Life
#      🎶 School High
#      🎶 What Happens
#
# ✅ Done! Collected 1900 total songs across 13 artists.

# %% [markdown]
# Ensuring that there aren't any songs that are different verisons of one another. Ex. remix verison etc.

# %%
def normalize_title(title):
    title = title.lower()
    # remove common remix or version suffixes
    title = re.sub(r'\(.*?\)', '', title)
    title = re.sub(r'[-–—:].*', '', title)
    return title.strip()

filtered.loc[:, 'title_clean'] = filtered['song_title'].apply(normalize_title)

dup_clean = (
    filtered.groupby(['artist', 'title_clean'])
    .size()
    .reset_index(name='count')
    .query('count > 1')
)
dup_clean.head()

filtered = filtered.drop_duplicates(subset=['artist', 'title_clean'], keep='first')

filtered['artist'].value_counts()
# Out:
# /var/folders/g4/t1q9yqqx7h36p5_2jzq23jsw0000gn/T/ipykernel_9677/4072658275.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered.loc[:, 'title_clean'] = filtered['song_title'].apply(normalize_title)
# artist
# Drake                   194
# Kanye West              153
# J. Cole                 150
# Soulja Boy              146
# Jay-Z                   142
# Joey Bada$$             139
# Mac Miller              137
# 2Pac                    133
# Kendrick Lamar          131
# Tyler, The Creator      129
# Quentin Miller          128
# Big L                   108
# A Tribe Called Quest    102
# Name: count, dtype: int64

# %%
filtered.to_csv('hiphop_corpus_with_lyrics.csv', index=False)
